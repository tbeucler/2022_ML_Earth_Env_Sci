# %% [markdown]
# <a href="https://colab.research.google.com/github/tbeucler/2022_ML_Earth_Env_Sci/blob/main/Lab_Notebooks/S5_2_ANNs_for_Climate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bonus Exercise 1: Emulating Convective Processes with Artificial Neural Networks for Climate Modeling

# %% [markdown]
# ![john-fowler-qQIb6343A8U-unsplash.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Storms rapidly transport heat and water in the atmosphere, regulating the Earth's climate. Can you predict how storms affect atmospheric temperatures using deep learning?
#
# *Source: Photo by <a href="https://unsplash.com/@wildhoney?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">John Fowler</a> licensed under the <a href='https://unsplash.com/license'>Unsplash License.</a>*

# %% [markdown]
# ## Part I: Pre-Processing the Dataset for Regression

# %% [markdown]
# ## Part II: Training and Testing an Artificial Neural Network

# %% [markdown]
# # Bonus Exercise 2: Helping our Neural Network Generalize Across Climate Using Physics-Guided Machine Learning

# %% [markdown]
# ## Part I: Physically Rescaling the Inputs to Facilitate Generalization

# %% [markdown]
# ## Part II: Towards "Climate-Invariant" Neural Networks
